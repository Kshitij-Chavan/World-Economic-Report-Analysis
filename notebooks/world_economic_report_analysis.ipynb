# %% [markdown]
# # World Economic Report Analysis

# %% [markdown]
# ## Preparing and QA Data

# %%
# Importing Libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# Setting Up style

plt.style.use("my_dark_creative.mplstyle")

# %%
# Importing Dataset world Bank Excel File

path = '../Data/World+Economic+Indicators/WorldBank.xlsx'


# Creating new column and renaming existing columns for better maneuverability

world_bank = pd.read_excel(path, parse_dates=['Year']).assign(
    population_millions = lambda x : x['GDP (USD)'] / (x['GDP per capita (USD)'] * 1000000)
).rename(columns = {
    'Country Name' : 'country',
    'Country Code' : 'country_code',
    'Region' : 'region',
    'IncomeGroup' : 'income_group',
    'Year' : 'year',
    'Birth rate, crude (per 1,000 people)' : 'birth_rate_1000_people',
    'Death rate, crude (per 1,000 people)' : 'death_rate_1000_people',
    'Electric power consumption (kWh per capita)' : 'electric_power_consumption_kwh',
    "individuals using the Internet (% of population)" : 'individuals_using_internet',
    'Infant mortality rate (per 1,000 live births)' : 'infant_mortality_rate',
    'Life expectancy at birth (years)' : 'life_expectancy',
    'Population density (people per sq. km of land area)' : 'population_density',
    'Unemployment (% of total labor force) (modeled ILO estimate)' : 'unemployment_ratio'
})

world_bank.head()
# Out:
#        country country_code      region income_group       year  \
# 0  Afghanistan          AFG  South Asia   Low income 2018-01-01
# 1  Afghanistan          AFG  South Asia   Low income 2017-01-01
# 2  Afghanistan          AFG  South Asia   Low income 2016-01-01
# 3  Afghanistan          AFG  South Asia   Low income 2015-01-01
# 4  Afghanistan          AFG  South Asia   Low income 2014-01-01
#
#    birth_rate_1000_people  death_rate_1000_people  \
# 0                     NaN                     NaN
# 1                  33.211                   6.575
# 2                  33.981                   6.742
# 3                  34.809                   6.929
# 4                  35.706                   7.141
#
#    electric_power_consumption_kwh     GDP (USD)  GDP per capita (USD)  \
# 0                             NaN  1.936300e+10               520.897
# 1                             NaN  2.019180e+10               556.302
# 2                             NaN  1.936260e+10               547.228
# 3                             NaN  1.990710e+10               578.466
# 4                             NaN  2.048490e+10               613.856
#
#    Individuals using the Internet (% of population)  infant_mortality_rate  \
# 0                                               NaN                   47.9
# 1                                             13.50                   49.5
# 2                                             11.20                   51.2
# 3                                              8.26                   53.1
# 4                                              7.00                   55.1
#
#    life_expectancy  population_density  unemployment_ratio  \
# 0              NaN             56.9378               1.542
# 1           64.130             55.5960               1.559
# 2           63.763             54.1971               1.634
# 3           63.377             52.7121               1.679
# 4           62.966             51.1148               1.735
#
#    population_millions
# 0            37.172416
# 1            36.296472
# 2            35.383058
# 3            34.413604
# 4            33.370856

# %%
world_bank.describe()
# Out:
#                                 year  birth_rate_1000_people  \
# count                          12449            11440.000000
# mean   1988-12-31 15:03:03.050847488               28.643276
# min              1960-01-01 00:00:00                6.900000
# 25%              1974-01-01 00:00:00               16.600000
# 50%              1989-01-01 00:00:00               27.545500
# 75%              2004-01-01 00:00:00               40.881250
# max              2018-01-01 00:00:00               58.227000
# std                              NaN               13.131893
#
#        death_rate_1000_people  electric_power_consumption_kwh     GDP (USD)  \
# count            11416.000000                     5848.000000  9.578000e+03
# mean                10.588539                     3175.294686  1.700740e+11
# min                  1.127000                        0.000000  8.824450e+06
# 25%                  6.863750                      390.385750  1.393010e+09
# 50%                  9.200000                     1541.895000  7.275305e+09
# 75%                 12.687000                     4313.767500  4.857782e+10
# max                 54.444000                    54799.200000  2.050000e+13
# std                  5.489382                     4467.139298  8.979866e+11
#
#        GDP per capita (USD)  Individuals using the Internet (% of population)  \
# count           9575.000000                                       5064.000000
# mean            8231.812259                                         23.334471
# min               34.790600                                          0.000000
# 25%              513.145500                                          0.594949
# 50%             1852.810000                                          8.406225
# 75%             7774.565000                                         41.295950
# max           189171.000000                                        100.000000
# std            16173.539954                                         28.319388
#
#        infant_mortality_rate  life_expectancy  population_density  \
# count            9984.000000     11176.000000        11845.000000
# mean               51.704437        64.044692          318.861370
# min                 1.400000        18.907000            0.098625
# 25%                14.475000        55.917750           19.783400
# 50%                37.000000        67.276000           64.007500
# 75%                78.200000        72.692250          144.823000
# max               279.400000        85.417100        21389.100000
# std                46.131039        11.491087         1593.406041
#
#        unemployment_ratio  population_millions
# count         5208.000000          9575.000000
# mean             8.295079            29.956728
# min              0.140000             0.008913
# 25%              3.687000             1.051937
# 50%              6.775000             5.390515
# 75%             11.212250            17.075158
# max             37.940000          1391.895280
# std              6.290703           115.803824

# %%
# Changing Datatypes

convert_dict = {
    'birth_rate_1000_people' : 'float16',
    'death_rate_1000_people' : 'float16',
    'income_group' : 'category',
    'electric_power_consumption_kwh' : 'float32',
    'infant_mortality_rate' : 'float16',
    'life_expectancy' : 'float16',
    'population_density' : 'float32',
    'unemployment_ratio' : 'float16',
    'population_millions' : 'float32',
}

world_bank = world_bank.astype(convert_dict)

# %%
# Checking Memory Usage and Data type that we have changed
world_bank.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12449 entries, 0 to 12448
# Data columns (total 16 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   country                                           12449 non-null  object
#  1   country_code                                      12449 non-null  object
#  2   region                                            12449 non-null  object
#  3   income_group                                      12449 non-null  category
#  4   year                                              12449 non-null  datetime64[ns]
#  5   birth_rate_1000_people                            11440 non-null  float16
#  6   death_rate_1000_people                            11416 non-null  float16
#  7   electric_power_consumption_kwh                    5848 non-null   float32
#  8   GDP (USD)                                         9578 non-null   float64
#  9   GDP per capita (USD)                              9575 non-null   float64
#  10  Individuals using the Internet (% of population)  5064 non-null   float64
#  11  infant_mortality_rate                             9984 non-null   float16
#  12  life_expectancy                                   11176 non-null  float16
#  13  population_density                                11845 non-null  float32
#  14  unemployment_ratio                                5208 non-null   float16
#  15  population_millions                               9575 non-null   float32
# dtypes: category(1), datetime64[ns](1), float16(5), float32(3), float64(3), object(3)
# memory usage: 2.8 MB

# %%
# Importing Human Development Index Data on year 2014

hdi_2014 = pd.read_csv('../Data/World+Economic+Indicators/HDI.csv', usecols=['iso3', 'hdi_2014'])

hdi_2014.head()
# Out:
#   iso3  hdi_2014
# 0  AFG     0.479
# 1  AGO     0.563
# 2  ALB     0.792
# 3  AND     0.871
# 4  ARE     0.859

# %%
# Filtering World Bank Data on Year 2014 and joining this on HDI csv file on country code

wb_hdi_2014 = pd.merge(
                world_bank.query("year.dt.year == 2014"), hdi_2014,
                left_on = 'country_code', right_on = 'iso3',
                how = 'left'
            )


wb_hdi_2014.head()
# Out:
#           country country_code                      region  \
# 0     Afghanistan          AFG                  South Asia
# 1         Albania          ALB       Europe & Central Asia
# 2         Algeria          DZA  Middle East & North Africa
# 3  American Samoa          ASM         East Asia & Pacific
# 4         Andorra          AND       Europe & Central Asia
#
#            income_group       year  birth_rate_1000_people  \
# 0            Low income 2014-01-01               35.718750
# 1   Upper middle income 2014-01-01               12.257812
# 2   Upper middle income 2014-01-01               25.531250
# 3   Upper middle income 2014-01-01               17.500000
# 4  High income: nonOECD 2014-01-01                     NaN
#
#    death_rate_1000_people  electric_power_consumption_kwh     GDP (USD)  \
# 0                7.140625                             NaN  2.048490e+10
# 1                7.218750                     2309.370117  1.322820e+10
# 2                4.710938                     1362.869995  2.140000e+11
# 3                4.199219                             NaN  6.430000e+08
# 4                     NaN                             NaN  3.350740e+09
#
#    GDP per capita (USD)  Individuals using the Internet (% of population)  \
# 0               613.856                                               7.0
# 1              4578.670                                              60.1
# 2              5493.060                                              29.5
# 3             11525.200                                               NaN
# 4             42300.300                                              95.9
#
#    infant_mortality_rate  life_expectancy  population_density  \
# 0              55.093750         62.96875           51.114799
# 1               8.898438         77.81250          105.442001
# 2              21.796875         75.87500           16.342501
# 3                    NaN              NaN          278.954987
# 4               3.199219              NaN          168.537994
#
#    unemployment_ratio  population_millions iso3  hdi_2014
# 0            1.735352            33.370857  AFG     0.479
# 1           17.484375             2.889092  ALB     0.792
# 2           10.203125            38.958248  DZA     0.735
# 3                 NaN             0.055791  NaN       NaN
# 4                 NaN             0.079213  AND     0.871

# %%
# Checking Summary

wb_hdi_2014.describe()
# Out:
#                       year  birth_rate_1000_people  death_rate_1000_people  \
# count                  211              204.000000              204.000000
# mean   2014-01-01 00:00:00               20.859375                7.691406
# min    2014-01-01 00:00:00                7.898438                1.126953
# 25%    2014-01-01 00:00:00               11.976562                5.835938
# 50%    2014-01-01 00:00:00               17.812500                7.500000
# 75%    2014-01-01 00:00:00               28.656250                9.218750
# max    2014-01-01 00:00:00               48.000000               16.437500
# std                    NaN               10.281250                2.707031
#
#        electric_power_consumption_kwh     GDP (USD)  GDP per capita (USD)  \
# count                      139.000000  2.010000e+02            201.000000
# mean                      4270.600586  3.907779e+11          17779.147856
# min                         39.055801  3.729180e+07            248.845000
# 25%                        858.174500  6.047810e+09           2163.160000
# 50%                       2588.300049  3.133500e+10           6684.800000
# 75%                       5478.100098  2.060000e+11          20258.000000
# max                      53832.500000  1.750000e+13         189171.000000
# std                       5981.463867  1.546117e+12          27113.375249
#
#        Individuals using the Internet (% of population)  \
# count                                        199.000000
# mean                                          45.738525
# min                                            0.990000
# 25%                                           17.730000
# 50%                                           46.160000
# 75%                                           69.890000
# max                                           98.160000
# std                                           28.934518
#
#        infant_mortality_rate  life_expectancy  population_density  \
# count             190.000000       197.000000          208.000000
# mean               23.859375        71.812500          424.474243
# min                 1.799805        49.906250            0.137154
# 25%                 6.800781        66.375000           36.550049
# 50%                15.046875        73.437500           88.684647
# 75%                36.781250        77.562500          210.380005
# max                93.000000        84.000000        19478.800781
# std                21.750000         8.132812         1986.298096
#
#        unemployment_ratio  population_millions    hdi_2014
# count          186.000000           201.000000  188.000000
# mean             8.078125            35.668407    0.709527
# min              0.189941             0.010972    0.370000
# 25%              3.767578             1.174332    0.581250
# 50%              6.515625             7.130571    0.732000
# 75%             10.804688            23.589827    0.824750
# max             28.031250          1359.233765    0.952000
# std              6.019531           136.957260    0.152831

# %% [markdown]
# ## Preparing Data for Visualization

# %%
# Creating Pivot Table For Showing Sum of GDP by region for each year

regions_gdp_year = world_bank.pivot_table(
    index = world_bank['year'].dt.year,
    columns = 'region',
    values = 'GDP (USD)',
    aggfunc = 'sum'
)

regions_gdp_year.head()
# Out:
# region  East Asia & Pacific  Europe & Central Asia  Latin America & Caribbean  \
# year
# 1960           1.464117e+11           2.834935e+11               5.739654e+10
# 1961           1.466530e+11           3.017402e+11               6.076987e+10
# 1962           1.499092e+11           3.299221e+11               9.396297e+10
# 1963           1.672525e+11           3.638093e+11               9.482963e+10
# 1964           1.921179e+11           4.028910e+11               1.056766e+11
#
# region  Middle East & North Africa  North America    South Asia  \
# year
# 1960                  1.410025e+10   5.430845e+11  4.746783e+10
# 1961                  1.480286e+10   6.046452e+11  5.062976e+10
# 1962                  1.464985e+10   6.479622e+11  5.403093e+10
# 1963                  1.646011e+10   6.848096e+11  6.077062e+10
# 1964                  1.817288e+10   7.362342e+11  6.960261e+10
#
# region  Sub-Saharan Africa
# year
# 1960          2.648878e+10
# 1961          2.753489e+10
# 1962          2.984425e+10
# 1963          3.419779e+10
# 1964          3.338035e+10

# %%
# Creating Pivot Table For Showing Sum of Population by region for each year

regions_population_years = world_bank.pivot_table(
                                index = world_bank['year'].dt.year,
                                columns = 'region',
                                values = 'population_millions',
                                aggfunc = 'sum'
                            )
                            
regions_population_years.head()
# Out:
# region  East Asia & Pacific  Europe & Central Asia  Latin America & Caribbean  \
# year
# 1960             872.149048             280.746704                 186.852631
# 1961             871.192810             283.656647                 192.312729
# 1962             881.036194             286.741455                 219.093140
# 1963             902.065857             289.789612                 225.199249
# 1964             922.572632             292.833191                 231.411896
#
# region  Middle East & North Africa  North America  South Asia  \
# year
# 1960                     59.303284     180.615845  572.526550
# 1961                     60.945297     201.909866  584.618164
# 1962                     62.667580     205.167984  597.165039
# 1963                     64.416443     208.371994  610.162231
# 1964                     66.231026     211.318878  623.598511
#
# region  Sub-Saharan Africa
# year
# 1960            168.518539
# 1961            172.577530
# 1962            177.066650
# 1963            181.468994
# 1964            186.049088

# %%
# Creating Table For Showing Average of Human Development Index by region in Year 2014

wb_hdi_by_region = wb_hdi_2014.groupby('region').agg({'hdi_2014' : 'mean'}).sort_values('hdi_2014', ascending = False)

wb_hdi_by_region
# Out:
#                             hdi_2014
# region
# North America               0.922000
# Europe & Central Asia       0.845320
# Latin America & Caribbean   0.739697
# Middle East & North Africa  0.736619
# East Asia & Pacific         0.729963
# South Asia                  0.611125
# Sub-Saharan Africa          0.527745

# %% [markdown]
# ## Visualizing The Data

# %%
# Standardized Region Color Palette
region_colors = {
    'East Asia & Pacific': '#4CD3C2',        # turquoise
    'South Asia': '#A68FFF',                 # violet
    'Sub-Saharan Africa': '#F6BD60',         # golden amber
    'Europe & Central Asia': '#F28482',      # coral red
    'Latin America & Caribbean': '#84A59D',  # gray-green
    'North America': '#C3C1E6',              # lavender
    'Middle East & North Africa': '#8FCB9B'  # mint green
}

# %%
# Plotting Stackchart for showing GDP growth of Regions Over the Years

fig,ax = plt.subplots()

# Sort Regions by there latest GDP (2018)
sort_region = regions_gdp_year.iloc[-1].sort_values(ascending = False).index

# Plotting Stackplot
ax.stackplot(
    regions_gdp_year.index,
    [regions_gdp_year[region] for region in sort_region],
    labels = sort_region,
    colors=[region_colors[region] for region in sort_region]
)

# Setting Title and Labels
ax.set_title('GDP Growth of Regions Over the Year',),
ax.set_xlabel('Year'),
ax.set_ylabel('GDP in Trillions')


ax.legend(bbox_to_anchor = (1.1,1))
plt.show()

# %%
# Plotting Stackchart for showing Population of Regions Over the Years

fig,ax = plt.subplots()

# Sort Regions by there latest GDP (2018)
sort_region = regions_population_years.iloc[-1].sort_values(ascending = False).index

# Plotting Stackplot
ax.stackplot(
    regions_population_years.index,
    [regions_population_years[region] for region in sort_region],
    labels = sort_region,
    colors=[region_colors[region] for region in sort_region]
)

# Setting Title and Labels
ax.set_title('Population of Regions Over the Year',),
ax.set_xlabel('Year'),
ax.set_ylabel('Population in Billions')


ax.legend(bbox_to_anchor = (1.1,1))
plt.show()

# %%
# Creating Bubble Chart

import matplotlib.ticker as mticker

fig,ax = plt.subplots() 

sns.scatterplot(
    data = wb_hdi_2014,
    x = 'life_expectancy',
    y = 'GDP per capita (USD)',
    hue = 'region',
    palette=region_colors,
    size = 'population_millions',
    sizes = (min(wb_hdi_2014['population_millions']), max(wb_hdi_2014['population_millions'])),
    legend = False
).set(yscale = 'log')

ax.set_title('Comparing Economic Prosperity and Longevity by Region — 2014')
ax.set_xlabel('Life Expectancy over Years')
ax.yaxis.set_major_formatter(mticker.ScalarFormatter())

plt.show()

# %%
# Bar Chart for showing Human Development ratio across regions

fig,ax = plt.subplots()

sns.barplot(
    data = wb_hdi_by_region,
    x = 'region',
    y = 'hdi_2014',
    hue = 'region',
    palette=region_colors,
    errorbar = None
)

ax.set_title('Human Development Index by Regions'),
ax.set_xlabel('Region'),
ax.set_ylabel('Avg Human Development Index')

plt.xticks(rotation = 90)
plt.show()

# %%
# Scatterplot

fig,ax = plt.subplots()

sns.scatterplot(
    data = wb_hdi_2014.query("country != 'Iceland'"),
    x = 'electric_power_consumption_kwh',
    y = 'GDP per capita (USD)',
    hue = 'hdi_2014',
    palette = 'coolwarm_r'
)

ax.set_title('Power Consumption and GDP Relation'),
ax.set_xlabel('Power Consumption (kwh)')

plt.show()
